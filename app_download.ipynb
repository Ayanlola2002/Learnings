# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayanlola2002/Learnings/blob/master/app_download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9fd3ae06-313b-4ad3-b77f-3abf32254be9" name="files[]" multiple disabled />
#      <output id="result-9fd3ae06-313b-4ad3-b77f-3abf32254be9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving app_download.csv to app_download.csv
# ...
